# %%
# Usual imports
import numpy as np
import pandas as pd
from tqdm import tqdm
import string
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import concurrent.futures
import time
import pyLDAvis.sklearn
from pylab import bone, pcolor, colorbar, plot, show, rcParams, savefig
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import os



# spaCy based imports
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
# !python -m spacy download nl_core_news_sm
# Out:
# C:\Users\krist\anaconda3\python.exe: No module named spacy

# %%
df = pd.read_csv('cleaned_test.csv')
df.head()
# Out:
#         Date                                              Title       Numac  \
# 0  1/14/2020  REGION DE BRUXELLES-CAPITALE\nREGION DE BRUXEL...  2020010053
# 1  1/24/2020  MINISTERE DE LA COMMUNAUTE FRANCAISE\n20 DECEM...  2020010214
# 2  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 20...  2020040138
# 3  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 20...  2020020094
# 4  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\nAdministratio...  2020010193
#
#                                              Link FR  \
# 0  http://www.ejustice.just.fgov.be/cgi/article.p...
# 1  http://www.ejustice.just.fgov.be/cgi/article.p...
# 2  http://www.ejustice.just.fgov.be/cgi/article.p...
# 3  http://www.ejustice.just.fgov.be/cgi/article.p...
# 4  http://www.ejustice.just.fgov.be/cgi/article.p...
#
#                                              Link NL  \
# 0  http://www.ejustice.just.fgov.be/cgi/article_b...
# 1  http://www.ejustice.just.fgov.be/cgi/article_b...
# 2  http://www.ejustice.just.fgov.be/cgi/article_b...
# 3  http://www.ejustice.just.fgov.be/cgi/article_b...
# 4  http://www.ejustice.just.fgov.be/cgi/article_b...
#
#                                                 Text  \
# 0  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgevi...
# 1  NL FR\n\neinde eerste woord laatste woord\nPub...
# 2  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgevi...
# 3  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgevi...
# 4  NL FR\n\neinde eerste woord laatste woord\nPub...
#
#                                         Cleaned Text  \
# 0   : 2020010053 BRUSSELS HOOFDSTEDELIJK GEWEST 8...
# 1   : 2020010214 MINISTERIE VAN DE FRANSE GEMEENS...
# 2   : 2020040138 FEDERALE OVERHEIDSDIENST FINANCI...
# 3   : 2020020094 FEDERALE OVERHEIDSDIENST FINANCI...
# 4   : 2020010193 FEDERALE OVERHEIDSDIENST FINANCI...
#
#                                            Summary_1  Summary_2  \
# 0  Demissionair minister van Financiën, belast me...        NaN
# 1  De Franse Gemeenschap en de Executieve van de ...        NaN
# 2  De ministers van Financiën en de staatssecreta...        NaN
# 3  Het ministerie van Financiën heeft het ministe...        NaN
# 4                                                NaN        NaN
#
#                                             Tag text
# 0    : 2020010053 BRUSSELS HOOFDSTEDELIJK GEWEST ...
# 1    : 2020010214 MINISTERIE VAN DE FRANSE GEMEEN...
# 2    : 2020040138 FEDERALE OVERHEIDSDIENST FINANC...
# 3    : 2020020094 FEDERALE OVERHEIDSDIENST FINANC...
# 4    : 2020010193 FEDERALE OVERHEIDSDIENST FINANC...

# %%
df.fillna('', inplace=True)

# %%
df['Tag text']=""

for idx, row in df.iterrows():

    nlp = spacy.load('nl_core_news_sm')
    text = df.loc[idx, 'Cleaned Text']
    tokenized = nlp(text)
    tokens = [token.text for token in tokenized]

    stopwords = spacy.lang.nl.stop_words.STOP_WORDS

    text_no_stop = [lemma for lemma in tokens if lemma not in stopwords]
    cleaned = ' '.join(text_no_stop)

    df.loc[idx,'Tag text'] = cleaned

# %%
doc = nlp(df["Tag text"][3])
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020020094
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  FEDERALE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OVERHEIDSDIENST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  FINANCIEN
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JANUARI 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  . - Ministerieel besluit aanpassing ministerieel besluit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  aanduiding gedelegeerde toepassing artikelen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73411
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73414
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  734quater1 koninklijk besluit uitvoering
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     De Vice-Eerste
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minister Financiën
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  , Gelet artikel
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2055
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ingevoegd wet
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 december 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ; Gelet koninklijk besluit uitvoering
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     734quater3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ; Gelet ministerieel besluit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  aanduiding gedelegeerde toepassing artikelen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73411
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73414
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  734quater1 koninklijk besluit uitvoering
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ; Gelet koninklijk besluit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line

# %%
df.to_excel("cleaned_test.xlsx", index=False)
df.to_csv("cleaned_test.csv", index=False, encoding="utf-8-sig")

# %%
# TfidfVectorizer 

from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd


tfidfvectorizer = TfidfVectorizer(analyzer='word')

# convert th documents into a matrix


tfidf_wm = tfidfvectorizer.fit_transform(df['Summary_1'])
tfidfvectorizer.get_feature_names_out()

print(tfidf_wm.shape)
# Out:
# (662, 2847)

# %%
NUM_TOPICS = 10

# %%
# Latent Dirichlet Allocation Model
lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=10, learning_method='online',verbose=True)
data_lda = lda.fit_transform(tfidf_wm)
# Out:
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %%
# Non-Negative Matrix Factorization Model
nmf = NMF(n_components=NUM_TOPICS)
data_nmf = nmf.fit_transform(tfidf_wm)

# %%
# Latent Semantic Indexing Model using Truncated SVD
lsi = TruncatedSVD(n_components=NUM_TOPICS)
data_lsi = lsi.fit_transform(tfidf_wm)

# %%
# Functions for printing keywords for each topic
def selected_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])

# %%
# Keywords for topics clustered by Latent Dirichlet Allocation
print("LDA Model:")
selected_topics(lda, tfidfvectorizer)
# Out:
# LDA Model:
# Topic 0:
# [('kunstendecreet', 0.3096560232349893), ('60', 0.30950662179854055), ('budget', 0.30949704945388845), ('indiendatum', 0.30942431807952003), ('immunoassay', 0.3094026165138431), ('voorschrift', 0.30864244476311237), ('vrijgemaakt', 0.30858330108337423), ('vergoedingsbasis', 0.30856364861163144), ('554982', 0.3085230380324343), ('beoordelingsronde', 0.3084039367718184)]
# Topic 1:
# [('grondwet', 5.243629527870734), ('hetgeen', 3.474277618501199), ('volgt', 3.148125863272838), ('aangenomen', 3.107679448228397), ('74', 3.097708343784169), ('volksvertegenwoordigers', 3.0235537700529527), ('bekrachtigen', 2.7507475273801005), ('wij', 2.696862790857278), ('kamer', 2.45548029799081), ('uit', 2.251510892800294)]
# Topic 2:
# [('2245bis', 5.750477604416362), ('mogen', 0.2993756898035802), ('zesde', 0.2992773707787663), ('talen', 0.29905799214920953), ('leger', 0.2989093755055768), ('1938', 0.2988320500831356), ('actief', 0.298826678123876), ('demissionairen', 0.2988229320861248), ('krijgsmacht', 0.2988079388450791), ('afleggen', 0.2975629131545836)]
# Topic 3:
# [('definitieve', 0.8548107376595836), ('de', 0.11370794144982665), ('van', 0.1110514826011049), ('het', 0.10843656213621367), ('en', 0.10834916374778114), ('in', 0.10782573273058992), ('voor', 0.10741106145057443), ('vlaamse', 0.10713709555893469), ('artikel', 0.10693681373894061), ('een', 0.10660859228359666)]
# Topic 4:
# [('demissionaire', 0.8554203797338362), ('belastbare', 0.5416764284261223), ('verschuldigde', 0.32240976977871), ('vak', 0.3217934185313448), ('onderscheid', 0.3198163687797185), ('procureur', 0.2976534994365207), ('rma', 0.29718624329195786), ('des', 0.2969545529234189), ('arbeidsauditeur', 0.29658346353200976), ('terbeschikkingstelling', 0.296329062911605)]
# Topic 5:
# [('de', 89.58210220662113), ('van', 83.90319561354991), ('het', 50.27406884116142), ('en', 31.163347171842144), ('in', 31.029572094377382), ('een', 28.042844828972367), ('heeft', 23.33191206394202), ('19', 23.295691545011042), ('covid', 22.363170338231676), ('besluit', 21.844489976070438)]
# Topic 6:
# [('...', 0.9827031785681407), ('schijf', 0.30379912518450813), ('psychiatrische', 0.3027845527505459), ('schijven', 0.3024500159656401), ('uitbetaald', 0.3005349940928171), ('voorschot', 0.14749228688325897), ('van', 0.11083187690176385), ('miljoen', 0.1100395354778196), ('de', 0.10937820684190624), ('500', 0.10775320321748243)]
# Topic 7:
# [('devon', 8.092694520934879), ('૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦૦००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००००', 4.274972620592945), ('анынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынанынаны ...
# Topic 8:
# [('de', 10.895327105351452), ('van', 8.155678575482952), ('belgië', 4.7321236961193796), ('grensarbeiders', 4.394167558451976), ('akkoord', 4.3652620149008445), ('brussels', 4.348122053524911), ('en', 4.022850436665125), ('in', 3.9153748472776364), ('het', 3.769299097916988), ('een', 3.745833396121092)]
# Topic 9:
# [('fraude', 0.3652477842865687), ('caf', 0.28320915252921586), ('gewestelijk', 0.28283211595858293), ('hulpcentrum', 0.28275915330552315), ('crac', 0.2827221291194708), ('reserves', 0.2826741882952233), ('hoogte', 0.28239652772396623), ('overschot', 0.28239579290416195), ('ontvangstenuitgaven', 0.2823894269852082), ('geboekt', 0.2821498396773519)]

# %%
# Keywords for topics clustered by Latent Semantic Indexing
print("NMF Model:")
selected_topics(nmf, tfidfvectorizer)
# Out:
# NMF Model:
# Topic 0:
# [('van', 1.4763662388640975), ('besluit', 1.061648444023689), ('het', 0.7509423435087368), ('tot', 0.7468664239634208), ('koninklijk', 0.5531625016892053), ('wijziging', 0.5292825163957093), ('de', 0.5114217286713603), ('2020', 0.40406545274217226), ('houdende', 0.3812804296581353), ('december', 0.3331237138584261)]
# Topic 1:
# [('decreet', 0.7945975013907962), ('van', 0.6179051455482085), ('machten', 0.5930222139806036), ('bijzondere', 0.5777771484112199), ('toekenning', 0.5543738633506361), ('17', 0.5077912145959931), ('gezondheidscrisis', 0.4948120096911782), ('maart', 0.45380592907959255), ('het', 0.4055546745671994), ('aan', 0.3941144079759016)]
# Topic 2:
# [('zaken', 0.8685888840804307), ('minister', 0.6776660038154957), ('buitenlandse', 0.5897008407079276), ('van', 0.5295988959219371), ('demissionair', 0.4461077799946123), ('ministerie', 0.42132053674421127), ('en', 0.39917922686140145), ('volksgezondheid', 0.3850575353917065), ('sociale', 0.2971249637455836), ('werkgelegenheid', 0.25358688550581415)]
# Topic 3:
