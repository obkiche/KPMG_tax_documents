# %%
import chardet
import pandas as pd

with open('./data/tax.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large


df = pd.read_csv('./data/tax.csv', encoding=result['encoding'])

df
# Out:
#           Date  \
# 0    1/14/2020
# 1    1/16/2020
# 2    1/16/2020
# 3    1/24/2020
# 4    1/28/2020
# ..         ...
# 764   4/4/2022
# 765   4/4/2022
# 766   4/4/2022
# 767   4/4/2022
# 768   4/5/2022
#
#                                                                                                    Title  \
# 0    REGION DE BRUXELLES-CAPITALE\nREGION DE BRUXELLES-CAPITALE\n8 JANVIER 2020. - Arrêté ministériel...
# 1    SERVICE PUBLIC FEDERAL INTERIEUR\n10 DECEMBRE 2017. - Arrêté royal modifiant l'arrêté royal n°  ...
# 2    SERVICE PUBLIC FEDERAL FINANCES\n7 DECEMBRE 2018. - Arrêté royal modifiant l'AR/CIR 92, en ce qu...
# 3    MINISTERE DE LA COMMUNAUTE FRANCAISE\n20 DECEMBRE 2019. - Arrêté ministériel approuvant le dossi...
# 4    SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 2020. - Arrêté royal remédiant au double emploi de l...
# ..                                                                                                   ...
# 764  SERVICE PUBLIC FEDERAL FINANCES\n29 MARS 2021. - Arrêté royal modifiant le tableau g, section pr...
# 765  SERVICE PUBLIC FEDERAL EMPLOI, TRAVAIL ET CONCERTATION SOCIALE\n31 MARS 2022. - Arrêté royal pro...
# 766  SERVICE PUBLIC FEDERAL SECURITE SOCIALE\n23 MARS 2022. - Arrêté royal modifiant l'arrêté royal n...
# 767  GOUVERNEMENTS DE COMMUNAUTE ET DE REGION\nREGION DE BRUXELLES-CAPITALE\nSERVICE PUBLIC REGIONAL ...
# 768  GOUVERNEMENTS DE COMMUNAUTE ET DE REGION\nCOMMUNAUTE FLAMANDE\nAUTORITE FLAMANDE\n11 FEVRIER 202...
#
#           Numac  \
# 0    2020010053
# 1    2020010044
# 2    2020040052
# 3    2020010214
# 4    2020040138
# ..          ...
# 764  2022020551
# 765  2022201913
# 766  2022031428
# 767    40002126
# 768  2022031529
#
#                                                                                                  Link FR  \
# 0    http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2020-01-14&caller=list&numa...
# 1    http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2020-01-16&caller=list&numa...
# 2    http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2020-01-16&caller=list&numa...
# 3    http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2020-01-24&caller=list&numa...
# 4    http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2020-01-28&caller=list&numa...
# ..                                                                                                   ...
# 764  http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2022-04-04&caller=list&numa...
# 765  http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2022-04-04&caller=list&numa...
# 766  http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2022-04-04&caller=list&numa...
# 767  http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2022-04-04&caller=list&numa...
# 768  http://www.ejustice.just.fgov.be/cgi/article.pl?language=fr&pub_date=2022-04-05&caller=list&numa...
#
#                                                                                                  Link NL  \
# 0    http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2020-01-14&caller=list...
# 1    http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2020-01-16&caller=list...
# 2    http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2020-01-16&caller=list...
# 3    http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2020-01-24&caller=list...
# 4    http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2020-01-28&caller=list...
# ..                                                                                                   ...
# 764  http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2022-04-04&caller=list...
# 765  http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2022-04-04&caller=list...
# 766  http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2022-04-04&caller=list...
# 767  http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2022-04-04&caller=list...
# 768  http://www.ejustice.just.fgov.be/cgi/article_body.pl?language=nl&pub_date=2022-04-05&caller=list...
#
#                                                                                                     Text
# 0    NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgeving\nRaad van State\nELI - Navigatie systeem via ee...
# 1    NL FR DE\nELI - Navigatie systeem via een Europese identificatiecode voor wetgeving\nhttp://www....
# 2    NL FR DE\nELI - Navigatie systeem via een Europese identificatiecode voor wetgeving\nhttp://www....
# 3    NL FR\n\neinde eerste woord laatste woord\nPublicatie : 2020-01-24\nNumac : 2020010214\nMINISTER...
# 4    NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgeving\nRaad van State\nELI - Navigatie systeem via ee...
# ..                                                                                                   ...
# 764  NL FR DE\nELI - Navigatie systeem via een Europese identificatiecode voor wetgeving\nhttp://www....
# 765  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgeving\nRaad van State\nELI - Navigatie systeem via ee...
# 766  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgeving\nRaad van State\nELI - Navigatie systeem via ee...
# 767                                                                                                   NL
# 768  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgeving\nRaad van State\nELI - Navigatie systeem via ee...
#
# [769 rows x 6 columns]

# %%
df = df[df["Text"].str.contains("Duitse vertaling")==False]

# %%
import nltk
nltk.download('stopwords') 
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mahboubeh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mahboubeh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Dataset
from sklearn.datasets import fetch_20newsgroups
# Data manipulation
import numpy as np
import pandas as pd
pd.options.display.max_colwidth = 100
# Text preprocessing and modelling
from nltk.tokenize import RegexpTokenizer
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.pipeline import Pipeline
# Visualisation
#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set(style='whitegrid', context='talk')
#from wordcloud import WordCloud
#import pyLDAvis
#import pyLDAvis.sklearn
# Warnings
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Stopwords
stop_words = stopwords.words("dutch")
stop_words.extend(['bis', 'NL', 'FR','artikel', "januari", "februari", "maart", "april", "mei", "juni", "juli", "augustus", "september", "oktober", "november", "december"])

# %%
def preprocess_text(document):
    """Preprocess document into normalised tokens."""
    # Tokenise words into alphabetic tokens with minimum length of 3
    tokeniser = RegexpTokenizer(r'[A-Za-z]{3,}')
    tokens = tokeniser.tokenize(document)
    
    # Tag words with POS tag
    pos_map = {'J': 'a', 'N': 'n', 'R': 'r', 'V': 'v'}
    pos_tags = pos_tag(tokens)
    
    # Lowercase and lemmatise 
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(t.lower(), pos=pos_map.get(p[0], 'v')) for t, p in pos_tags]
    
    # Remove stopwords
    keywords= [lemma for lemma in lemmas if lemma not in stop_words]
    return keywords

# %%
# converting the given text term-document matrix
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(analyzer=preprocess_text, max_features=1500, min_df=10)
X = vectorizer.fit_transform(df['Text'])
words = np.array(vectorizer.get_feature_names())

print(X)
print("X = ", words)
# Out:
#   (0, 111)	0.018863336361580132
#   (0, 110)	0.06172989286107297
#   (0, 1481)	0.05333701188664241
#   (0, 1128)	0.057673151459785486
#   (0, 1006)	0.059298731560354985
#   (0, 993)	0.053746284740344104
#   (0, 73)	0.05846717815079254
#   (0, 894)	0.04812334397345867
#   (0, 250)	0.024184534693548622
#   (0, 609)	0.042948284982115545
#   (0, 1214)	0.039224343580573216
#   (0, 87)	0.042223287809336256
#   (0, 229)	0.09095037860103435
#   (0, 50)	0.041139049727374095
#   (0, 47)	0.025589905717999656
#   (0, 871)	0.05178894274103149
#   (0, 1455)	0.02776745679343073
#   (0, 1009)	0.05642454710158097
#   (0, 439)	0.027673097642339717
#   (0, 728)	0.023727419654922047
#   (0, 1487)	0.04422658494231266
#   (0, 207)	0.05274041443075089
#   (0, 1031)	0.06417312822025165
#   (0, 224)	0.13527365707250036
#   (0, 1490)	0.08851897636836419
#   :	:
#   (661, 848)	0.012204997461731135
#   (661, 995)	0.012204997461731135
#   (661, 704)	0.012204997461731135
#   (661, 1466)	0.02440999492346227
#   (661, 351)	0.04271749111605897
#   (661, 356)	0.006102498730865567
#   (661, 1096)	0.0066209818446117796
#   (661, 184)	0.3347379176826426
#   (661, 408)	0.00755025473687414
#   (661, 660)	0.007561938923183412
#   (661, 357)	0.007573645557510917
#   (661, 1468)	0.00743462885197425
#   (661, 586)	0.007446093203979309
#   (661, 594)	0.007573645557510917
#   (661, 389)	0.00740036464944623
#   (661, 1338)	0.00725407338129936
#   (661, 1126)	0.007503740760672894
#   (661, 822)	0.007573645557510917
#   (661, 361)	0.015123877846366825
#   (661, 1101)	0.022791379549222484
#   (661, 1005)	0.022407260463151994
#   (661, 1452)	0.01475525684842281
#   (661, 698)	0.007764076721260423
#   (661, 726)	0.0077761786145993834
#   (661, 147)	0.007298713150866458
# X =  ['aandelen' 'aangebracht' 'aangegeven' ... 'zoverre' 'zowel' 'zullen']
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Applying Non-Negative Matrix Factorization
# Importing Necessary packages

from sklearn.decomposition import NMF

nmf = NMF(n_components=2, solver="mu")
W = nmf.fit_transform(X)
H = nmf.components_

for i, topic in enumerate(H):
     print("Topic {}: {}".format(i + 1, ",".join([str(x) for x in words[topic.argsort()[-5:]]])))
# Out:
# Topic 1: woord,covid,gelet,meet,besluit
# Topic 2: onderwijs,decreet,regering,franse,gemeenschap
# C:\Users\Mahboubeh\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:289: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(
