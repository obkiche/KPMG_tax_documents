# %%
import pandas as pd
import spacy

# %%
df = pd.read_csv('cleaned_test.csv')
df.head(10)
# Out:
#         Date                                              Title       Numac  \
# 0  1/14/2020  REGION DE BRUXELLES-CAPITALE\nREGION DE BRUXEL...  2020010053
# 1  1/24/2020  MINISTERE DE LA COMMUNAUTE FRANCAISE\n20 DECEM...  2020010214
# 2  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 20...  2020040138
# 3  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 20...  2020020094
# 4  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\nAdministratio...  2020010193
# 5  1/29/2020  MINISTERE DE LA COMMUNAUTE FRANCAISE\n20 DECEM...  2020020106
# 6   2/3/2020  SERVICE PUBLIC FEDERAL FINANCES\n9 DECEMBRE 20...  2020040181
# 7  2/11/2020  SERVICE PUBLIC FEDERAL FINANCES\n11 DECEMBRE 2...  2020030083
# 8  2/13/2020  SERVICE PUBLIC FEDERAL FINANCES\nADMINISTRATIO...  2020030053
# 9  2/13/2020  SERVICE PUBLIC FEDERAL FINANCES\nADMINISTRATIO...  2020030054
#
#                                              Link FR  \
# 0  http://www.ejustice.just.fgov.be/cgi/article.p...
# ...

# %%
from keybert import KeyBERT

for idx, row in df.loc[:20].iterrows():
    doc = df['Tag text']
    kw_model = KeyBERT()
    keywords = kw_model.extract_keywords(doc)
    print(keywords)
# Out:
# None
# None
# None
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       3 for idx, row in df.loc[:20].iterrows():
#       4     doc = df['Tag text']
# ----> 5     kw_model = KeyBERT()
#       6     keywords = kw_model.extract_keywords(doc)
#       7     print(keywords)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keybert\_model.py:50, in KeyBERT.__init__(self, model)
#      35 def __init__(self, model="all-MiniLM-L6-v2"):
#      36     """KeyBERT initialization
#      37
#      38     Arguments:
#    (...)
#      48                   * https://www.sbert.net/docs/pretrained_models.html
#      49     """
# ---> 50     self.model = select_backend(model)
#
# File ~\anaconda3\envs\tf\lib\site-packages\keybert\backend\_utils.py:47, in select_backend(embedding_model)
#      45 # Create a Sentence Transformer model based on a string
# ...
