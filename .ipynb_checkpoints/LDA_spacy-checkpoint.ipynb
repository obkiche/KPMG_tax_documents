# %%
# Usual imports
import numpy as np
import pandas as pd
from tqdm import tqdm
import string
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import concurrent.futures
import time
import pyLDAvis.sklearn
from pylab import bone, pcolor, colorbar, plot, show, rcParams, savefig
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import os



# spaCy based imports
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
# !python -m spacy download nl_core_news_sm
# Out:
# C:\Users\krist\anaconda3\python.exe: No module named spacy

# %%
df = pd.read_csv('KPMG Tax Case - CSV_Summarized.csv')
df.head()
# Out:
#         Date                                              Title       Numac  \
# 0  1/14/2020  REGION DE BRUXELLES-CAPITALE\nREGION DE BRUXEL...  2020010053
# 1  1/24/2020  MINISTERE DE LA COMMUNAUTE FRANCAISE\n20 DECEM...  2020010214
# 2  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 20...  2020040138
# 3  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\n20 JANVIER 20...  2020020094
# 4  1/28/2020  SERVICE PUBLIC FEDERAL FINANCES\nAdministratio...  2020010193
#
#                                              Link FR  \
# 0  http://www.ejustice.just.fgov.be/cgi/article.p...
# 1  http://www.ejustice.just.fgov.be/cgi/article.p...
# 2  http://www.ejustice.just.fgov.be/cgi/article.p...
# 3  http://www.ejustice.just.fgov.be/cgi/article.p...
# 4  http://www.ejustice.just.fgov.be/cgi/article.p...
#
#                                              Link NL  \
# 0  http://www.ejustice.just.fgov.be/cgi/article_b...
# 1  http://www.ejustice.just.fgov.be/cgi/article_b...
# 2  http://www.ejustice.just.fgov.be/cgi/article_b...
# 3  http://www.ejustice.just.fgov.be/cgi/article_b...
# 4  http://www.ejustice.just.fgov.be/cgi/article_b...
#
#                                                 Text  \
# 0  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgevi...
# 1  NL FR\n\neinde eerste woord laatste woord\nPub...
# 2  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgevi...
# 3  NL FR\nbelgiëlex.be   -  Kruispuntbank Wetgevi...
# 4  NL FR\n\neinde eerste woord laatste woord\nPub...
#
#                                         Cleaned Text  \
# 0   : 2020010053 BRUSSELS HOOFDSTEDELIJK GEWEST 8...
# 1   : 2020010214 MINISTERIE VAN DE FRANSE GEMEENS...
# 2   : 2020040138 FEDERALE OVERHEIDSDIENST FINANCI...
# 3   : 2020020094 FEDERALE OVERHEIDSDIENST FINANCI...
# 4   : 2020010193 FEDERALE OVERHEIDSDIENST FINANCI...
#
#                                            Summary_1  Summary_2
# 0  Demissionair minister van Financiën, belast me...        NaN
# 1  De Franse Gemeenschap en de Executieve van de ...        NaN
# 2  De ministers van Financiën en de staatssecreta...        NaN
# 3  Het ministerie van Financiën heeft het ministe...        NaN
# 4                                                NaN        NaN

# %%
df.fillna('', inplace=True)

# %%
df['Tag text']=""

for idx, row in df.iterrows():

    nlp = spacy.load('nl_core_news_sm')
    text = df.loc[idx, 'Cleaned Text']
    tokenized = nlp(text)
    tokens = [token.text for token in tokenized]

    stopwords = spacy.lang.nl.stop_words.STOP_WORDS

    text_no_stop = [lemma for lemma in tokens if lemma not in stopwords]
    cleaned = ' '.join(text_no_stop)

    df.loc[idx,'Tag text'] = cleaned

# %%
doc = nlp(df["Tag text"][3])
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">  :
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020020094
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  FEDERALE
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OVERHEIDSDIENST
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  FINANCIEN
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JANUARI 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  . - Ministerieel besluit aanpassing ministerieel besluit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  aanduiding gedelegeerde toepassing artikelen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73411
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73414
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  734quater1 koninklijk besluit uitvoering
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     De Vice-Eerste
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  Minister
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Minister Financiën
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  , Gelet artikel
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2055
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ingevoegd wet
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 december 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ; Gelet koninklijk besluit uitvoering
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , artikel
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     734quater3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ; Gelet ministerieel besluit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 december 2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  aanduiding gedelegeerde toepassing artikelen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73411
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     73414
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  734quater1 koninklijk besluit uitvoering
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wetboek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inkomstenbelastingen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1992
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ; Gelet koninklijk besluit
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line

# %%
df.to_excel("cleaned_test.xlsx", index=False)
df.to_csv("cleaned_test.csv", index=False, encoding="utf-8-sig")

# %%
# TfidfVectorizer 

from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd


tfidfvectorizer = TfidfVectorizer(analyzer='word')

# convert th documents into a matrix


tfidf_wm = tfidfvectorizer.fit_transform(df['Tag text'])
tfidfvectorizer.get_feature_names_out()

print(tfidf_wm.shape)
# Out:
# (662, 20929)

# %%
NUM_TOPICS = 10

# %%
# Latent Dirichlet Allocation Model
lda = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=10, learning_method='online',verbose=True)
data_lda = lda.fit_transform(tfidf_wm)
# Out:
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10

# %%
# Non-Negative Matrix Factorization Model
nmf = NMF(n_components=NUM_TOPICS)
data_nmf = nmf.fit_transform(tfidf_wm)

# %%
# Latent Semantic Indexing Model using Truncated SVD
lsi = TruncatedSVD(n_components=NUM_TOPICS)
data_lsi = lsi.fit_transform(tfidf_wm)

# %%
# Functions for printing keywords for each topic
def selected_topics(model, vectorizer, top_n=10):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-top_n - 1:-1]])

# %%
# Keywords for topics clustered by Latent Dirichlet Allocation
print("LDA Model:")
selected_topics(lda, )
# Out:
# LDA Model:
# Topic 0:
# [('2020', 0.14179453026788905), ('bel', 0.13505738861359554), ('nace', 0.13441165345448353), ('code', 0.12862033572749287), ('overeenkomst', 0.12647226743970877), ('besluit', 0.12647093826597902), ('artikel', 0.12532189402951327), ('koninklijk', 0.12477619019517609), ('gelet', 0.12272894541724493), ('19', 0.12181409099928825)]
# Topic 1:
# [('relatives', 0.437075217998743), ('modifications', 0.4167647881154457), ('titre', 0.39370244012035843), ('ajoutee', 0.18691235448887164), ('confirmation', 0.18611173287188754), ('enregistrement', 0.18458708855188585), ('greffe', 0.18441543557707293), ('divers', 0.18407364166119708), ('arrete', 0.1838190344385638), ('valeur', 0.18334515832649745)]
# Topic 2:
# [('31122021', 0.5264898734354219), ('1012021', 0.5259777439854704), ('ingraving', 0.37181135772326934), ('804', 0.3394320970155201), ('738', 0.2693299847772257), ('607', 0.2651789993141868), ('336', 0.2568606055355108), ('542', 0.22962457899265418), ('673', 0.22370679364741167), ('869', 0.21358735272394425)]
# Topic 3:
# [('triage', 0.10768300183711486), ('diamant', 0.10764796654980752), ('kind', 0.10665919697934173), ('gezinsbijslagen', 0.10654022013793642), ('synthetische', 0.10638420529393679), ('handelaren', 0.1063617994897726), ('zelfstandige', 0.10634447180572072), ('omwille', 0.10620513578330182), ('vakantiedagen', 0.10620458519315211), ('artikel', 0.10617866483341616)]
# Topic 4:
# [('identificatienummer', 0.1083183035055077), ('2020', 0.10710800341117911), ('naam', 0.10687422761557311), ('regering', 0.1068668123520364), ('overwegende', 0.10663784475242084), ('adres', 0.10656700223289943), ('covid', 0.10648661301808102), ('verzending', 0.1064257366320043), ('besluit', 0.10638657823515082), ('19', 0.10620504800861418)]
# Topic 5:
# [('directiecomité', 0.11081060074858305), ('voorzitter', 0.10921788855639492), ('kmo', 0.10881136701362172), ('vennootschap', 0.10855159766911893), ('centrum', 0.10814018422169325), ('besluit', 0.10771512181970203), ('identificatienummer', 0.1075851219926721), ('zetel', 0.10750298036138786), ('artikel', 0.10736276090943692), ('wetboek', 0.10712764234694695)]
# Topic 6:
# [('2020', 0.10779246636683584), ('the', 0.10767189034890277), ('artikel', 0.10707198207840539), ('steun', 0.10686328933877931), ('raadpleging', 0.10669776077614523), ('regering', 0.10661004735275362), ('waalse', 0.1065862831807019), ('beroepsverliezen', 0.10645377999307924), ('maart', 0.1062408170327542), ('vitale', 0.10618194932078419)]
# Topic 7:
# [('artikel', 41.011263127571425), ('2020', 40.30973113849325), ('besluit', 39.8984185529567), ('gelet', 34.87620509607759), ('2021', 33.051492293859376), ('19', 30.928111022552503), ('covid', 29.147386902160978), ('regering', 27.88549960450658), ('wet', 25.038454877015834), ('de', 24.125649288074715)]
# Topic 8:
# [('akkoord', 0.13533907416825508), ('onderling', 0.12269276533993431), ('autoriteiten', 0.1223733646928116), ('bevoegde', 0.12179468277762305), ('belgië', 0.12015373882899116), ('luxemburg', 0.11895457641733874), ('2020', 0.11681583279002063), ('duitsland', 0.11612758292026135), ('overleg', 0.11545466313983545), ('frankrijk', 0.11309525752545112)]
# Topic 9:
# [('artikel', 0.11191280861651134), ('2020', 0.11106324470255693), ('vlaamse', 0.11069542581585604), ('besluit', 0.10983191898664506), ('regering', 0.10967784117303535), ('covid', 0.10919938694438389), ('agentschap', 0.10859200789225072), ('franse', 0.10847017171363835), ('decreet', 0.10845101128868224), ('19', 0.10831089650426036)]

# %%
# Keywords for topics clustered by Latent Semantic Indexing
print("NMF Model:")
selected_topics(nmf, tfidfvectorizer)
# Out:
# NMF Model:
# Topic 0:
# [('2020', 0.8287381780896311), ('koninklijk', 0.7539954346340891), ('besluit', 0.6477211357507594), ('gelet', 0.5738841752955748), ('covid', 0.5695645270746533), ('19', 0.5515411284315654), ('artikel', 0.4963758234238924), ('maatregelen', 0.49610564221999276), ('wet', 0.493910499777956), ('coronavirus', 0.42919595876257094)]
# Topic 1:
# [('franse', 1.086569535258148), ('gemeenschap', 1.080715028999917), ('regering', 0.5378017744393051), ('2020', 0.32584344479776706), ('onderwijs', 0.3042807081007697), ('bijzondere', 0.29333135605952926), ('machten', 0.2757197296524651), ('decreet', 0.2706490501459327), ('ambtenarenzaken', 0.25345411159343756), ('promotie', 0.23679822139165269)]
# Topic 2:
# [('akkoord', 0.8202654356889039), ('bevoegde', 0.5487710644367642), ('autoriteiten', 0.5407926888099067), ('belgië', 0.5210108735237939), ('onderling', 0.5163452803920507), ('overeenkomst', 0.4918735911165889), ('2020', 0.44935157386429), ('luxemburg', 0.34190166760335844), ('overleg', 0.3393972736732176), ('duitsland', 0.31512024200420113)]
# Topic 3:
# [('bel', 1.0761423552589708), ('nace', 1.045108101338309), ('code', 0.8110713925106603), ('personeelsbestand', 0.333414986673519), ('onderneming', 0.309545164845689), ('verordening', 0.29199632066207165), ('ondernemingen', 0.2641715298537031), ('93', 0.22234150023018737), ('tegemoetkoming', 0.2155465707427524), ('kleine', 0.18468937323669138)]
# Topic 4:
# [('vlaamse', 1.0901743407738196), ('decreet', 0.4649014479249309), ('vermeld', 0.3751828630930954), ('onderwijs', 0.33251317451966), ('besluit', 0.3259674446155326), ('artikel', 0.3254255875402459), ('regering', 0.2975516372559314), ('lid', 0.24086858656292415), ('de', 0.23657852436233504), ('subsidie', 0.2329267476917114)]
# Topic 5:
# [('brusselse', 0.6829439923982896), ('hoofdstedelijke', 0.6316309049697606), ('steun', 0.37882454857008263), ('regering', 0.3613095029323499), ('ordonnantie', 0.3267694070469224), ('brussels', 0.2768265724217181), ('hoofdstedelijk', 0.26530633804117515), ('gewest', 0.2379019218069215), ('ondernemingen', 0.23358191605448297), ('2020', 0.21269143138216653)]
# Topic 6:
# [('artikel', 0.5081633824834788), ('wetboek', 0.49136102540217985), ('woorden', 0.3605123510536459), ('wet', 0.3437041765976849), ('lid', 0.3124565190478728), ('inkomstenbelastingen', 0.29717445230013434), ('art', 0.2913953406710689), ('vervangen', 0.27896169150062194), ('december', 0.2719060679500754), ('1992', 0.2627031488593272)]
# Topic 7:
# [('waalse', 0.8834574391274842), ('gelet', 0.4835707226385455), ('overwegende', 0.37992437381222677), ('regering', 0.3756879530194936), ('2021', 0.337827365359125), ('besluit', 0.282866556695878), ('19', 0.22138245069154658), ('decreet', 0.2146993830724537), ('covid', 0.20448088168124512), ('2020', 0.18630353639123146)]
# Topic 8:
# [('gemeenschapscommissie', 0.6502634661463162), ('college', 0.5523145891792561), ('gemeenschappelijke', 0.46707580223681183), ('verenigd', 0.4614960360678754), ('ordonnantie', 0.26563102234067465), ('samenwerkingsakkoord', 0.21611929812360936), ('duitstalige', 0.2093106768104895), ('gezondheid', 0.20878782995607859), ('personen', 0.20302121651205893), ('19', 0.18574537996710552)]
# Topic 9:
# [('06', 0.42668857616788675), ('2021', 0.4216214542637551), ('provisioneel', 0.40529377235581854), ('uitgavenbegroting', 0.4028929703356532), ('begrotingsjaar', 0.376396238629166), ('fod', 0.3299059124549609), ('programma', 0.31388936885697594), ('90', 0.28414618882595544), ('krediet', 0.27816821176527873), ('wet', 0.25699985292530186)]

# %%
# Keywords for topics clustered by Non-Negative Matrix Factorization
print("LSI Model:")
selected_topics(lsi, tfidfvectorizer)
# Out:
# LSI Model:
# Topic 0:
# [('2020', 0.25176443194233555), ('besluit', 0.22365445769494988), ('artikel', 0.21440110211796196), ('gelet', 0.20391690671228793), ('19', 0.1837195152548483), ('regering', 0.18242355790157552), ('covid', 0.17449653586628358), ('2021', 0.16756424461416844), ('overwegende', 0.13936774991794285), ('gemeenschap', 0.13465952748737206)]
# Topic 1:
